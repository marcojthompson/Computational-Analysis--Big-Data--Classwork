# %% [markdown]
# # Week 7: Natural language processing

# %% [markdown]
# The exercises today are about extracting high-level knowledge from text. We're still a long way from computers being able to give us insight as deep as that which we can aquire from manually reading text, but some the tools that you will use today get us a long way in understanding useful things about unreadibly large amount of text in comparatively little time. In the exercises today you will:
#
# * Create wordclouds
# * Extract sentiment from text
# * Construct a Bag of Words (BoW) matrix to represent how words are used about each faction in the Marvel dataset
# * Perform a TD-IDF transform to understand which words are important to different characters

# %% [markdown]
# ### Part 0: Clean text

# %% [markdown]
# The first task when working with text, is almost always to somehow clean the text. In our case, text is formatted
# as Mediawiki markup, which has its quirks as you probably remember. So we need to clean this text and most of the
# way we need to do it manually. But while this is a meaningful thing to learn to do, we don't want to take time away from the more important exercises
# that come later in this exercise set. Therefore, you will find a helper function in this notebook that extracts and cleans the markup text of a Wikipedia page.  Remember to change the path so that it points to the data folder on your computer.

# %%
import re
import nltk

nltk.download('stopwords')

# Get a list of stopwords from nltk
stop_words = nltk.corpus.stopwords.words("english")
stop_words += ["ref", "name", "p"]

#print(stopwords)

def get_clean_text(filename, faction):
    def _isnum(w):
        try:
            int(w)
            return True
        except ValueError:
            return False
        
    # Load markup
    with open(f"../../data/{faction}/{filename}.txt") as fp:
        text = fp.read()
        
    # Remove table and external links
    markup_text = re.sub(r'\{\{[\s\S]*?\}\}', '', text)

    # Remove category links
    markup_text = re.sub(r'\[\[Category.+\]\]', '', markup_text)

    # Set words to lowercase and remove them if they are stop words
    words = [w.lower() for w in re.findall('\w+', markup_text) if w.lower() not in stop_words]

    # Remove numbers
    words = [w for w in words if not _isnum(w)]
    
    #Convert to a string so word clould doesn't throw a hissy fit
    final_words = ""
    for w in words:
        final_words += w + " "
    
    return final_words
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/thompsmj/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Example
print(get_clean_text('Black Widow (Natasha Romanova)', 'heroes'))
# Out:
# aliases natalia shostakova natasha romanoff natalie rushman laura matthers mary farrell oktober black widow yelena belova yelena belova partners captain america br bucky barnes winter soldier br hawkeye clint barton hawkeye br daredevil marvel comics character daredevil supports powers expert espionage spy military tactics tactician master martial artist hand hand combatant slowed aging enhanced immune system expert marksman mastery various weapons skilled hypnosis hypnotist equipment via gauntlets grappling hook knock gas taser explosives tear gas pellets radio transmitter cat super subcat marvel comics hero sortkey black widow marvel comics black widow natalia alianovna natasha romanova russian language russian наталья альяновна наташа романова wolverine origins sept fiction al character arts character appearing american comic book published marvel comics created editor plotter stan lee scripter rico artist heck character debuted tales suspense april character introduced russia n espionage spy antagonist superhero iron man later defection defected united states becoming agent fictional spy agency h e l member superhero team avengers comics avengers character appeared numerous forms media animated television series video games films scarlett johansson portraying natasha romanoff marvel cinematic universe character several marvel cinematic universe films including iron man avengers film avengers captain america winter soldier avengers age ultron captain america civil war avengers infinity war cameo captain marvel film captain marvel avengers endgame black widow film black widow ever anderson portrayed young natasha black widow lake bell voices alternate reality versions character disney animated series tv series publication history file tales suspense jpg thumb upright left tales suspense april debut black widow cover art jack kirby paul reinman black widow first appearances recurring non costumed russia n espionage spy antagonist feature iron man beginning tales suspense april five issues later recruits besotted costumed archer later superhero hawkeye clint barton hawkeye cause government later supplies first black widow costume high tech weaponry eventually defects united states appearing temporarily brainwashed u superhero team series avengers comic avengers july widow later becomes recurring ally team officially becoming 16th member many years later black widow visually updated amazing spider man july reintroduced shoulder length red hair instead former short black hair skintight black costume wristbands fired spider threads would become appearance commonly associated character back45 short order black widow starred series amazing adventures aug sept sharing split book feature inhumans black widow feature dropped eight issues inhumans feature followed soon ending issue back45 immediately initial solo feature ended black widow co starred daredevil marvel comics series daredevil nov aug cover titled daredevil black widow daredevil writer gerry conway recounted idea team daredevil black widow mainly fan natasha thought daredevil would interesting chemistry back45 succeeding writers however felt daredevil worked better solo hero gradually wrote black widow series back45 immediately recast super team series champions team champions leader titular superhero group ran issues oct jan throughout 1980s 1990s black widow appeared frequently avengers member freelance agent h e l starred serialized feature within omnibus comic book series marvel fanfare aug march written george pérez ralph macchio editor ralph macchio art penciller perez stories later collected oversized one shot comics one shot black widow web intrigue june widow guest starred issues solo avengers force works iron man marvel team comics made frequent guest appearances daredevil since late 1970s starred three issue arc fire next time writer scott lobdell penciller randy green journey mystery feb april new ongoing black widow comic title debuted april first story arc wr ...

# %% [markdown]
# ### Part 1: Wordcloud

# %% [markdown]
# Although they probably offer more buzz than usefulness, wordclouds are a fun way to get quick insight into which words are used in a corpus of text. In this section you will generate some.  We start with an example generating a wordcloud for Iron Man.
#
# > *Hint: You must install `wordcloud` with anaconda by typing into your console*
# >
# >        conda install -c conda-forge wordcloud
# >
# >*or*
# >
# >        pip install wordcloud

# %%
#wordcloud example
from wordcloud import WordCloud
import matplotlib.pylab as plt

ironman_text = get_clean_text("Black Widow (Natasha Romanova)", "heroes")

wc_ironman = WordCloud(max_font_size=40).generate(ironman_text)

plt.figure(figsize=(20, 8))

plt.subplot(1, 3, 1)
plt.imshow(wc_ironman, interpolation="bilinear")

# %% [markdown]
# >**Ex. 7.1.1**: Make a word cloud for each faction using the `wordcloud` module! Use `max_font_size=40` to make the wordcloud managable.
#
# >* For each faction, concatenate all (cleaned) text about each character into one long string.
# >* Make three plots with appropriate titles, so we can compare them visually.
# >* You could choose to exclude all character names from the strings, that may give more interesting results. Not a requirement.
# >* Comment on the differences you see.

# %%
#Answer to 7.1.1
import os
from tqdm import tqdm

#Create a list of categories to make the code more concise 
character_categories = ['heroes', 'villains', 'ambiguous']
heroes_words = ""
villains_words = ""
ambiguous_words = ""

#Iterate through the folder for each character type
for character_category in character_categories:
    filepath = '../../data/%s'%character_category
    
    #iterate through all the files
    for file in tqdm(os.scandir(filepath)):
        f = open(file, "r")
        #Get the words
        words_to_be_added = get_clean_text(f.name.split("/")[-1][0:-4], character_category)
        #Add to the correct string
        if character_category == 'heroes':
            heroes_words += words_to_be_added
        elif character_category == 'villains':
            villains_words += words_to_be_added
        else:
            ambiguous_words += words_to_be_added
            
#Create a word cloud for each faction
wc_heroes = WordCloud(max_font_size=40).generate(heroes_words)

plt.figure(figsize=(20, 8))

plt.subplot(1, 3, 1)
plt.imshow(wc_heroes, interpolation="bilinear")     

wc_villains = WordCloud(max_font_size=40).generate(villains_words)

plt.figure(figsize=(20, 8))

plt.subplot(1, 3, 1)
plt.imshow(wc_villains, interpolation="bilinear")   

wc_ambiguous = WordCloud(max_font_size=40).generate(ambiguous_words)

plt.figure(figsize=(20, 8))

plt.subplot(1, 3, 1)
plt.imshow(wc_ambiguous, interpolation="bilinear")
# Out:
# 446it [00:06, 70.13it/s]
# 649it [00:07, 84.51it/s]
# 105it [00:01, 65.28it/s]

# %% [markdown]
# #Answer to 7.1.1 cont.
#
# I noticed how "kill" and "killed" were both in the bottom right for villains and ambiguous characters, but not for heroes. Spider Man is also quite popular in all three, but he's the biggest in the ambiguous category. Another interesting thing to note is how "death" appears in great quantities in heroes and villains, but not ambiguous characters.

# %% [markdown]
# ### Part 2: Sentiment analysis

# %% [markdown]
# Let's say you have an enormous amount of text, and you want to know something about its level of negativity, neutrality or positivity. Enter *Sentiment Analysis*. The point of this exercise is to extract the sentiment of text on your heroes, villains and ambiguous characters and figure out whether Wikipedia is biased towards writing in a certain tone towards a certain kind of characters.

# %% [markdown]
# >**Ex. 7.2.1**: Compute and visualize sentiment scores.
# * Using the `VADER` algorithm supported in `nltk` (i.e. `from nltk.sentiment.vader import SentimentIntensityAnalyzer`), you can obtain three scores for a piece of text: it's inferred negativity, neutrality and positivity.
# * Use `SentimentIntensityAnalyzer` to get these three scores for each character. Then, for each faction, make three distribution plots (e.g. histograms), that each show how negativity, neutrality and positivity are distributed, respectively. That's 9 plots in total.
# * In each of these plots, report the mean of the distribution. Your plot should look [something along the lines of this](https://dhsvendsen.github.io/images/sentiment_histograms.png).
# * Comment on your result. Does writing in Wikipedia seem biased to you?

# %%
#Answer to 7.2.1
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import statistics

#Initialize the analyzer
model = SentimentIntensityAnalyzer()

#Create a list of categories to make the code more concise 
character_categories = ['heroes', 'villains', 'ambiguous']

"""
#Create the lists needed for the scores
heroes_sentiment_scores_pos = []
heroes_sentiment_scores_neu = []
heroes_sentiment_scores_neg = []
villains_sentiment_scores_pos = []
villains_sentiment_scores_neu = []
villains_sentiment_scores_neg = []
ambiguous_sentiment_scores_pos = []
ambiguous_sentiment_scores_neu = []
ambiguous_sentiment_scores_neg = []

#Iterate through the folder for each character type
for character_category in character_categories:
    filepath = '../../data/%s'%character_category
    
    #iterate through all the files
    for file in tqdm(os.scandir(filepath)):
        f = open(file, "r")
        #Add to the correct lists
        if character_category == 'heroes':
            #Get the words
            words = get_clean_text(f.name.split("/")[-1][0:-4], character_category)
            #Calculate the sentiment scores
            scores = model.polarity_scores(words)
            #Add them to the respective lists
            heroes_sentiment_scores_pos.append(scores["pos"])
            heroes_sentiment_scores_neu.append(scores["neu"])
            heroes_sentiment_scores_neg.append(scores["neg"])
        elif character_category == 'villains':
            #Get the words
            words = get_clean_text(f.name.split("/")[-1][0:-4], character_category)
            #Calculate the sentiment scores
            scores = model.polarity_scores(words)
            #Add them to the respective lists
            villains_sentiment_scores_pos.append(scores["pos"])
            villains_sentiment_scores_neu.append(scores["neu"])
            villains_sentiment_scores_neg.append(scores["neg"])
        else: #character_category == "ambiguous"
            #Get the words
            words = get_clean_text(f.name.split("/")[-1][0:-4], character_category)
            #Calculate the sentiment scores
            scores = model.polarity_scores(words)
            #Add them to the respective lists
            ambiguous_sentiment_scores_pos.append(scores["pos"])
            ambiguous_sentiment_scores_neu.append(scores["neu"])
            ambiguous_sentiment_scores_neg.append(scores["neg"])
  
"""
"""
print(heroes_sentiment_scores_pos[0],
    heroes_sentiment_scores_neu[0],
    heroes_sentiment_scores_neg[0],
    villains_sentiment_scores_pos[0],
    villains_sentiment_scores_neu[0],
    villains_sentiment_scores_neg[0],
    ambiguous_sentiment_scores_pos[0],
    ambiguous_sentiment_scores_neu[0],
    ambiguous_sentiment_scores_neg[0])
"""


#Creat the histograms
plt.subplots()
plt.xlim(0, 1)
plt.hist(heroes_sentiment_scores_pos)
plt.title("Hero positive semtiment scores")
plt.show()
print("Mean score: " + str(statistics.mean(heroes_sentiment_scores_pos)))

plt.subplots()
plt.xlim(0, 1)
plt.hist(heroes_sentiment_scores_neu)
plt.title("Hero neutral semtiment scores")
plt.show()
print("Mean score: " + str(statistics.mean(heroes_sentiment_scores_neu)))

plt.subplots()
plt.xlim(0, 1)
plt.hist(heroes_sentiment_scores_neg)
plt.title("Hero negative semtiment scores")
plt.show()
print("Mean score: " + str(statistics.mean(heroes_sentiment_scores_neg)))

plt.subplots()
plt.xlim(0, 1)
plt.hist(villains_sentiment_scores_pos)
plt.title("Villains positive semtiment scores")
plt.show()
print("Mean score: " + str(statistics.mean(villains_sentiment_scores_pos)))

plt.subplots()
plt.xlim(0, 1)
plt.hist(villains_sentiment_scores_neu)
plt.title("Villains neutral semtiment scores")
plt.show()
print("Mean score: " + str(statistics.mean(villains_sentiment_scores_neu)))

plt.subplots()
plt.xlim(0, 1)
plt.hist(villains_sentiment_scores_neg)
plt.title("Villains negative semtiment scores")
plt.show()
print("Mean score: " + str(statistics.mean(villains_sentiment_scores_neg)))

plt.subplots()
plt.xlim(0, 1)
plt.hist(ambiguous_sentiment_scores_pos)
plt.title("Ambiguous positive semtiment scores")
plt.show()
print("Mean score: " + str(statistics.mean(ambiguous_sentiment_scores_pos)))

plt.subplots()
plt.xlim(0, 1)
plt.hist(ambiguous_sentiment_scores_neu)
plt.title("Ambiguous neutral semtiment scores")
plt.show()
print("Mean score: " + str(statistics.mean(ambiguous_sentiment_scores_neu)))

plt.subplots()
plt.xlim(0, 1)
plt.hist(ambiguous_sentiment_scores_neg)
plt.title("Ambiguous negative semtiment scores")
plt.show()
print("Mean score: " + str(statistics.mean(ambiguous_sentiment_scores_neg)))
# Out:
# Mean score: 0.16045067264573992
# Mean score: 0.7227578475336323
# Mean score: 0.11682959641255605
# Mean score: 0.15792141756548536
# Mean score: 0.6971093990755007
# Mean score: 0.1449568567026194
# Mean score: 0.15354285714285715
# Mean score: 0.6993904761904762
# Mean score: 0.1471047619047619

# %% [markdown]
# #Answer to 7.2.1 cont.
#
# My plots look a bit different than the examples, likely due to differences in the characters in each dataset. It seems the wiki pages tend to be more neutral than not, regardless of

# %% [markdown]
# ### Part 3: Bag of Words matrix

# %% [markdown]
# Intuitively, "Bag of Words" means breaking up a document into words and throwing them into a bag. And that's very close to the truth! In week 5 you constructed a "team-affiliations" matrix which had a row for each character and a column for each team. If the character was on a given team there would be a one for that character row at that team column, if not there would be a zero. The BoW is the same, only now, rather than teams, your columns are individual words that a character's wikipage might contain, and the numbers represent how many times those words appear.
# <img src="http://ulfaslak.com/computational_analysis_of_big_data/exer_figures/example_bow.png" width="400"/>
# BoW's are pretty large and sparse (mostly contain zero's) matrices, but they are extremely useful because they allow us to use linear algebra to do things like PCA, classification, etc..
#
# Here is a function for extracting a cleaned list of words from a string of text:

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string

# Get list of stopwords and add a few
stop_words = set(stopwords.words('english'))

def get_clean_words(text, exclude_words=[]):
    """Given some text, return a list of clean words.
    
    Input
    -----
        text : str
        exclude_words : list
            Words to exclude (e.g. characters own name)
    
    Output
    ------
        words : list
        
    Example
    -------
        >>> my_text = get_clean_text('Iron Man', 'heroes')
        >>> my_words = get_clean_words(my_text, exclude_words=['Iron', 'Man'])
    """

    # Extarct words
    words = word_tokenize(text)
    
    # Add exclude words to words to give it same treatment
    words += exclude_words
    
    # Convert to lower case
    words = [w.lower() for w in words]
    
    # Clear punctuation
    table = str.maketrans('', '', string.punctuation)
    words = [w.translate(table) for w in words]
    
    # Seperate words and exclude words
    if len(exclude_words) > 0:
        exclude_words = words[-len(exclude_words):]
        words = words[:-len(exclude_words)]
    
    # Remove non-alphabetic words
    words = [w for w in words if w.isalpha()]
    
    # Remove stop words
    words = [w for w in words if not w in stop_words | set(exclude_words)]
    
    # Remove single letter words 
    words = [w for w in words if len(w) > 1]

    return words

# %% [markdown]
# >**Ex. 7.3.1**: Create a bag of words matrix that contains all your characters. Maintain also a target array, so you know whether a row corresponds to a hero, a villain or an ambiguous character. Also, **do not include words that only appear for one character**.
# >*Hint: Since you already extracted lists of words for each faction in Ex. 7.1.1, you can use these to figure out what the total vocabulary of words used in your dataset is. You can "clean up" this vocabulary by a number of tricks. For example, there are tools for *stemming* words to remove grammar so that e.g. 'cat' and 'cats' both become 'cat', but that's all up to you whether you want to go that deep.*

# %% [markdown]
# 1. How many different words are in your vocabulary/columns are in your matrix?

# %% [markdown]
# 2. Print the 10 most used words, and the 10 least used words, along with their usage count.

# %% [markdown]
# 3. Plot the distribution of how many times words are used. Scale it appropriately. What does this distribution look like?

# %% [markdown]
# > **Ex. 7.3.2.EXTRA**: Fit a PCA to your BoW matrix. Make a bar plot that shows the explained variance ratio of the first 20 components. What fraction of the total variance do the first 20 components explain?
# >
# > ***Earn up to 5 extra credit points for solving this problem.***

# %% [markdown]
# > **Ex. 7.3.3.EXTRA**: Create a classifier that predicts if a character is a hero or a villain (not ambiguous) from the words used on their page. Report its 10-fold cross validation accuracy. Comment on the result and compare this score with the one obtained in week 5 where you trained on team alliances.
# >
# > ***Earn up to 5 extra credits for solving this problem.***

# %% [markdown]
# ### Part 4: TF-IDF

# %% [markdown]
# You didn't just make that BoW matrix to count simple things. We are interested in knowing how (or if) words are used differently across characters, and the best way to do that is to used something called a Term Frequency - Inverse Document Frequency (TF-IDF) transformation. You can read more about it [on Wikipedia](https://en.wikipedia.org/wiki/Tf%E2%80%93idf), but the gist is that it reflects how important each word is to each document (a document in this case being a character) in the chorpus.
#
# It works in two steps:
# * (1 - TF) you normalize over the frequency of each word in each document, so that rows sum to 1. Every row is now a probability distribution that gives the "term frequency" in each document.
# * (2 - IDF) you weigh the TF by the inverse document frequency, which measures how unique a word to specific documents. For example, the word "the" will be frequently used in every document (high TF) but we know it's not very special because it's used in all documents so the inverse document frequency is low, yielding a vanishing TF-IDF score for "the" in all documents.

# %% [markdown]
# >**Ex. 7.4.1**: Use any tool you like (you can do it manually, it's straight forward if you understand the method), to perform a TF-IDF transform on your BoW matrix from Ex. 7.3.1. The result should be a matrix of the same shape as the BoW, but with different values inside.

# %% [markdown]
# 1. Explain what these values mean.

# %% [markdown]
# 2. For the top three most written about characters in each class (so 9 in total), print out each of their 10 highest scoring words. Comment on any differences you observe in the type of words being used in different classes.

# %% [markdown]
# >**Ex. 7.4.2**: Install `umap-learn` and import it like `import umap`. UMAP is an algorithm for non-linear dimensionality reduction, that will allow you to visualize your data on a low-dimensional manifold. Using UMAP, transform the TF-IDF transformed BoW matrix into a 2-dimensional space. Plot the points in this space, colored by faction. Comment on the result.
